# %% [markdown]
# # 🛡️ Watermark Manager - Colab Edition
# This notebook allows you to run the standalone Watermark Manager on Google Colab.
#
# **Benefits of Colab:**
# - Public Gradio links work 100% of the time.
# - High-performance CPU/GPU for faster video processing.
# - No local firewall issues.

# %% [markdown]
# ### 1. Upload your files
# Upload the `Watermark_Modules` folder and requirements to Colab's file explorer on the left.

# %%
# @title 2. Install Dependencies
# !pip install gradio google-generativeai python-dotenv python-telegram-bot Pillow opencv-python numpy

# %%
# @title 3. Configure Environment
import os

# Fill these in!
os.environ['GEMINI_API_KEY'] = "YOUR_KEY_HERE"
os.environ['TELEGRAM_BOT_TOKEN'] = "YOUR_BOT_TOKEN_HERE"
os.environ['ENABLE_GRADIO'] = "true"
os.environ['ENABLE_TELEGRAM'] = "false" # Set to true if you want the bot too
os.environ['GRADIO_SHARE'] = "true"
os.environ['GRADIO_PORT'] = "7860"

print("✅ Environment variables set locally.")

# %%
# @title 4. Launch Application
# This will start both Gradio (with a public link) and Telegram if enabled.
# !python Watermark_Modules/watermark_main.py run
